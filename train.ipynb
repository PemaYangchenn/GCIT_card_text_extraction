# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install pytesseract
# !sudo apt-get install tesseract-ocr-ind
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-ind is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
import cv2
import numpy as np
import pytesseract
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = cv2.imread("/content/drive/MyDrive/ADL_PRJ/img/IMG-20240423-WA0000.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img)

# %%
real_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(real_img)

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread("/content/drive/MyDrive/ADL_PRJ/img/IMG_20240409_002401.jpg")

# Check if the image was read successfully
if img is None:
    print("Failed to read the image. Check the file path and permissions.")
else:
    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Denoise the grayscale image
    denoised = cv2.fastNlMeansDenoising(gray, None, h=10, templateWindowSize=7, searchWindowSize=21)

    # Display the denoised grayscale image using matplotlib
    plt.imshow(denoised, cmap='gray')
    plt.title('Denoised Grayscale Image')
    plt.axis('off')
    plt.show()

# %%
th, threshed =cv2.threshold(gray, 127, 255, cv2.THRESH_TRUNC)

# %%
result = pytesseract.image_to_string((threshed), lang="ind")

# %%
result
# Out:
# 'Dorji Wangmo\nBScin CS\n\nA\n\nGender : Female\nCID No. 11208002904\nI.D. No: 12210051\n\n \n\x0c'

# %%
import re

# OCR result
ocr_result = "Dorji Wangmo\nBScin CS\n\nA\n\nGender : Female\nCID No. 11208002904\nI.D. No: 12210051\n\n \n\x0c"

# Define a regular expression pattern to match each line
pattern = r'([^\n]+)\n'

# Find all matches using the pattern
matches = re.findall(pattern, ocr_result)

# Display the extracted lines
for line in matches:
    print(line)
# Out:
# Dorji Wangmo
# BScin CS
# A
# Gender : Female
# CID No. 11208002904
# I.D. No: 12210051
